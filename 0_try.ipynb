# %%
print("Q")
# Out:
# Q

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import trafilatura
from readability import Document


def scrape_website(base_url):
    # 儲存已處理的 URL
    visited_urls = set()

    # 結果儲存
    scraped_data = []

    def scrape_page(url, should_follow_links=True):
        # 如果 URL 已被訪問，跳過
        # Remove fragment identifier from URL
        url = url.split("#")[0]

        if url in visited_urls:
            return

        # 標記 URL 為已訪問
        visited_urls.add(url)
        print("Scraping", url)

        try:
            # 發送請求
            response = requests.get(url, timeout=10)
            response.raise_for_status()

            # 使用 BeautifulSoup 解析原始內容
            soup = BeautifulSoup(response.text, "html.parser")
            text_raw = soup.get_text(separator=" ", strip=True)

            # 使用 trafilatura 提取主要內容
            text_trafilatura = trafilatura.extract(response.text)

            # 使用 readability 提取主要內容
            doc = Document(response.text)
            text_readability = BeautifulSoup(doc.summary(), "html.parser").get_text(
                separator=" ", strip=True
            )

            # 抓取所有連結
            links = []
            for a_tag in soup.find_all("a", href=True):
                link = urljoin(url, a_tag["href"])  # 解析相對路徑為絕對路徑
                links.append(link)

            # 儲存資料
            scraped_data.append(
                {
                    "url": url,
                    # "text_raw": text_raw,
                    "content": text_trafilatura,
                    # "text_readability": text_readability,
                    "links": links,
                }
            )

            # 只有當 should_follow_links 為 True 且是同域名時才遞迴抓取
            if should_follow_links:
                for link in links:
                    # 檢查是否同域名
                    if is_same_domain(link, base_url):
                        scrape_page(link, should_follow_links=True)
                    else:
                        # 如果不是同域名，只抓取該頁面但不遞迴
                        scrape_page(link, should_follow_links=False)

        except requests.RequestException as e:
            print(f"Failed to scrape {url}: {e}")

    def is_same_domain(link, base_url):
        # 檢查連結是否與基底網址同網域
        base_netloc = urlparse(base_url).netloc
        link_netloc = urlparse(link).netloc
        return base_netloc == link_netloc

    # 開始抓取
    scrape_page(base_url, should_follow_links=True)

    return scraped_data


# 測試爬蟲
if __name__ == "__main__":
    base_url = "https://docs.bucketprotocol.io"
    result = scrape_website(base_url)

    # 輸出結果
    import json

    with open("scraped_data.json", "w", encoding="utf-8") as f:
        json.dump(result, f, ensure_ascii=False, indent=4)

    print("Scraping complete. Data saved to scraped_data.json.")
# Out:
# Scraping https://docs.bucketprotocol.io
# Scraping https://docs.bucketprotocol.io/
# Scraping https://bucketprotocol.io
# Scraping https://twitter.com/bucket_protocol
# Scraping https://discord.gg/wJWY5hq3Gx
# Scraping https://docs.bucketprotocol.io/introduction/key-advantages
# Scraping https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
# Scraping https://docs.bucketprotocol.io/mechanisms/system-overview
# Scraping https://docs.bucketprotocol.io/mechanisms/terminology
# Scraping https://docs.bucketprotocol.io/mechanisms/borrowing
# Scraping https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
# Scraping https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
# Scraping https://docs.bucketprotocol.io/mechanisms/peg-stability-module
# Scraping https://docs.bucketprotocol.io/mechanisms/redemptions
# Scraping https://docs.bucketprotocol.io/mechanisms/recovery-mode
# Scraping https://docs.bucketprotocol.io/mechanisms/flash-loan
# Scraping https://docs.bucketprotocol.io/mechanisms/protocol-revenue
# Scraping https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
# Scraping https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
# Scraping https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
# Scraping https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
# Scraping https://docs.bucketprotocol.io/outro/oracles
# Scraping https://docs.bucketprotocol.io/outro/security
# Scraping https://docs.bucketprotocol.io/outro/faq
# Scraping https://docs.bucketprotocol.io/outro/contracts
# Scraping https://docs.bucketprotocol.io/outro/links
# Scraping https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
# Scraping https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
# Scraping https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
# Scraping https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
# Scraping https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
# Scraping https://www.gitbook.com/?utm_source=content&utm_medium=trademark&utm_campaign=wUcWattcSzL6wK5QPKbk
# Scraping https://docs.bucketprotocol.io/external-audits-and-analysis
# Scraping https://app.bucketprotocol.io/
# Scraping https://docs.bucketprotocol.io/cdn-cgi/l/email-protection
# Scraping https://www.cloudflare.com/sign-up?utm_source=email_protection
# Failed to scrape https://www.cloudflare.com/sign-up?utm_source=email_protection: 403 Client Error: Forbidden for url: https://dash.cloudflare.com/sign-up
# Scraping https://support.cloudflare.com/hc/en-us/articles/200170016-What-is-Email-Address-Obfuscation-
# Failed to scrape https://support.cloudflare.com/hc/en-us/articles/200170016-What-is-Email-Address-Obfuscation-: 403 Client Error: Forbidden for url: https://support.cloudflare.com/hc/en-us/articles/200170016-What-is-Email-Address-Obfuscation-
# Scraping https://support.cloudflare.com/hc/en-us/categories/200275218-Getting-Started
# Failed to scrape https://support.cloudflare.com/hc/en-us/categories/200275218-Getting-Started: 403 Client Error: Forbidden for url: https://support.cloudflare.com/hc/en-us/categories/200275218-Getting-Started
# Scraping https://www.cloudflare.com/5xx-error-landing
# Scraping https://docs.bucketprotocol.io/outro
# Scraping https://bucketprotocol.io/
# Scraping https://t.me/bucketprotocol
# Scraping https://discord.com/invite/wJWY5hq3Gx
# Scraping https://docs.switchboard.xyz/
# Scraping https://pyth.network/
# Scraping https://supraoracles.com/
# Scraping https://docs.bucketprotocol.io/mechanisms
# Scraping https://sparkling.finance
# Scraping https://app.bucketprotocol.io/?tab=swap
# Scraping https://docs.bucketprotocol.io/bucket-campaign
# Scraping https://suiwallet.com/
# Scraping https://app.bucketprotocol.io/?tab=swap&from=0x2::sui::SUI&to=BUCK
# Scraping https://app.cetus.zone/swap?from=0x2::sui::SUI&to=0xce7ff77a83ea0cb6fd39bd8748e2ec89a3f41e8efdc3f4eb123e0ca37b184db2::buck::BUCK
# Scraping https://app.bucketprotocol.io/?tab=borrow&token=SUI
# Scraping https://app.bucketprotocol.io/?tab=earn&token=BUCK&suiwallet=true
# Scraping https://docs.bucketprotocol.io/introduction
# Scraping complete. Data saved to scraped_data.json.

# %%
type(result)
# Out:
# list

# %%
from collections import Counter
from collections import defaultdict


def remove_common_sections(scraped_data):
    # 找出所有連續5個以上的文字片段
    def get_ngrams(text, n):
        words = text.split()
        return [" ".join(words[i : i + n]) for i in range(len(words) - n + 1)]

    # 收集所有文件中的文字片段
    all_ngrams = []
    ngram_locations = defaultdict(list)  # 記錄每個片段出現的位置

    for item in scraped_data:
        text = item["text_content"]
        url = item["url"]
        # 取得5個以上文字的片段
        for n in range(5, 11):
            ngrams = get_ngrams(text, n)
            all_ngrams.extend(ngrams)
            # 記錄每個片段出現的URL
            for ngram in ngrams:
                ngram_locations[ngram].append(url)

    # 計算片段出現次數
    ngram_counts = Counter(all_ngrams)
    common_ngrams = {
        ngram
        for ngram, count in ngram_counts.items()
        if count > len(scraped_data) * 0.5
    }

    # 打印重複的部分及其位置
    print("重複出現的文字片段及其位置:")
    for ngram in common_ngrams:
        print(f"- {ngram}")
        print("  出現於:")
        for url in set(ngram_locations[ngram]):  # 使用set去除重複URL
            print(f"  * {url}")
        print()

    # 移除每個文件中的重複片段
    for item in scraped_data:
        text = item["text_content"]
        for ngram in common_ngrams:
            text = text.replace(ngram, "")
        # 清理多餘空格
        item["text_content"] = " ".join(text.split())

    return scraped_data

# %%
remove_common_sections(result)
# Out:
# 重複出現的文字片段及其位置:
# - | Bucket Campaign Savings Mode Flash & Depeg Scenarios
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Flash & Depeg Scenarios Security this page
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Savings Mode Flash & Depeg Scenarios Security this page
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Flash & Depeg Scenarios Security
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - | Bucket Campaign Savings Mode
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Bucket Campaign Savings Mode Flash
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Mode Flash & Depeg Scenarios Security this page
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Campaign Savings Mode Flash & Depeg Scenarios Security this
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Savings Mode Flash & Depeg Scenarios Security
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Mode Flash & Depeg Scenarios Security
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - | Bucket Campaign Savings Mode Flash
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Campaign Savings Mode Flash &
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - | Bucket Campaign Savings Mode Flash & Depeg Scenarios Security
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Mode Flash & Depeg Scenarios
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Campaign Savings Mode Flash & Depeg Scenarios Security
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - & Depeg Scenarios Security this
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Savings Mode Flash & Depeg Scenarios
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Campaign Savings Mode Flash & Depeg Scenarios
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Mode Flash & Depeg Scenarios Security this
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Bucket Campaign Savings Mode Flash & Depeg Scenarios Security
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Bucket Campaign Savings Mode Flash & Depeg Scenarios Security this
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Savings Mode Flash & Depeg Scenarios Security this
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Savings Mode Flash & Depeg
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/mechanisms
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment
#   * https://docs.bucketprotocol.io/outro/security
#   * https://docs.bucketprotocol.io/outro
#   * https://docs.bucketprotocol.io/mechanisms/terminology
#   * https://docs.bucketprotocol.io/mechanisms/protocol-revenue
#   * https://docs.bucketprotocol.io/mechanisms/peg-stability-module
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg
#   * https://docs.bucketprotocol.io/outro/contracts
#   * https://docs.bucketprotocol.io/mechanisms/system-overview
#   * https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations
#   * https://docs.bucketprotocol.io/outro/faq
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit
#   * https://docs.bucketprotocol.io/bucket-campaign
#   * https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign
#   * https://docs.bucketprotocol.io/introduction/key-advantages
#
# - Flash & Depeg Scenarios Security this
#   出現於:
#   * https://docs.bucketprotocol.io/price-stability-and-depeg-analysis
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service
#   * https://docs.bucketprotocol.io/
#   * https://docs.bucketprotocol.io/outro/links
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification
#   * https://docs.bucketprotocol.io/external-audits-and-analysis/introduction
#   * https://docs.bucketprotocol.io/mechanisms/flash-loan
#   * https://docs.bucketprotocol.io/outro/oracles
#   * https://docs.bucketprotocol.io/mechanisms/recovery-mode
#   * https://docs.bucketprotocol.io/mechanisms/redemptions
#   * https://docs.bucketprotocol.io/mechanisms/borrowing
#   * https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck
# ...
#    'https://docs.bucketprotocol.io/outro/contracts',
#    'https://docs.bucketprotocol.io/outro/links',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/introduction',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-1.-eligibility',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-2.-access-to-the-interface',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-3.-proprietary-rights',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-4.-prohibited-activity',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-5.-no-professional-advice-or-fiduciary-duties',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-6.-no-warranties',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-7.-compliance-obligations',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-8.-assumption-of-risk',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-9.-third-party-resources-and-promotions',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-10.-release-of-claims',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-11.-indemnity',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-12.-limitation-of-liability',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-13.-dispute-resolution',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-14.-class-action-and-jury-trial-waiver',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-15.-governing-law',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-16.-entire-agreement',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-17.-privacy-policy',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-1.-eligibility',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-2.-access-to-the-interface',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-3.-proprietary-rights',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-3.1-ownership',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-3.2-user-submitted-materials',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-3.3-feedback',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-3.4-license',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-4.-prohibited-activity',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-5.-no-professional-advice-or-fiduciary-duties',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-6.-no-warranties',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-7.-compliance-obligations',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-8.-assumption-of-risk',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-9.-third-party-resources-and-promotions',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-10.-release-of-claims',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-11.-indemnity',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-12.-limitation-of-liability',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-13.-dispute-resolution',
#    'https://docs.bucketprotocol.io/cdn-cgi/l/email-protection',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-14.-class-action-and-jury-trial-waiver',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-15.-governing-law',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-16.-entire-agreement',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service#id-17.-privacy-policy',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment']},
#  {'url': 'https://docs.bucketprotocol.io/external-audits-and-analysis',
#   'text_content': 'Introduction Security GitBook',
#   'links': ['https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/introduction/key-advantages',
#    'https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign',
#    'https://docs.bucketprotocol.io/mechanisms/system-overview',
#    'https://docs.bucketprotocol.io/mechanisms/terminology',
#    'https://docs.bucketprotocol.io/mechanisms/borrowing',
#    'https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck',
#    'https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations',
#    'https://docs.bucketprotocol.io/mechanisms/peg-stability-module',
#    'https://docs.bucketprotocol.io/mechanisms/redemptions',
#    'https://docs.bucketprotocol.io/mechanisms/recovery-mode',
#    'https://docs.bucketprotocol.io/mechanisms/flash-loan',
#    'https://docs.bucketprotocol.io/mechanisms/protocol-revenue',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details',
#    'https://docs.bucketprotocol.io/outro/oracles',
#    'https://docs.bucketprotocol.io/outro/security',
#    'https://docs.bucketprotocol.io/outro/faq',
#    'https://docs.bucketprotocol.io/outro/contracts',
#    'https://docs.bucketprotocol.io/outro/links',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/introduction',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service']},
#  {'url': 'https://docs.bucketprotocol.io/cdn-cgi/l/email-protection',
#   'text_content': 'Email Protection | Cloudflare Please enable cookies. Email Protection You are unable to access this email address bucketprotocol.io The website from which you got to this page is protected by Cloudflare. Email addresses on that page have been hidden in order to keep them from being accessed by malicious bots. You must enable Javascript in your browser in order to decode the e-mail address . If you have a website and are interested in protecting it in a similar way, you can sign up for Cloudflare . How does Cloudflare protect email addresses on website from spammers? Can I sign up for Cloudflare? Cloudflare Ray ID: 908c10a6f8e513b1 • Your IP: Click to reveal 174.181.85.77 • Performance & security by Cloudflare',
#   'links': []},
#  {'url': 'https://docs.bucketprotocol.io/outro',
#   'text_content': 'Oracles Security GitBook',
#   'links': ['https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/introduction/key-advantages',
#    'https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign',
#    'https://docs.bucketprotocol.io/mechanisms/system-overview',
#    'https://docs.bucketprotocol.io/mechanisms/terminology',
#    'https://docs.bucketprotocol.io/mechanisms/borrowing',
#    'https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck',
#    'https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations',
#    'https://docs.bucketprotocol.io/mechanisms/peg-stability-module',
#    'https://docs.bucketprotocol.io/mechanisms/redemptions',
#    'https://docs.bucketprotocol.io/mechanisms/recovery-mode',
#    'https://docs.bucketprotocol.io/mechanisms/flash-loan',
#    'https://docs.bucketprotocol.io/mechanisms/protocol-revenue',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details',
#    'https://docs.bucketprotocol.io/outro/oracles',
#    'https://docs.bucketprotocol.io/outro/security',
#    'https://docs.bucketprotocol.io/outro/faq',
#    'https://docs.bucketprotocol.io/outro/contracts',
#    'https://docs.bucketprotocol.io/outro/links',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/introduction',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service']},
#  {'url': 'https://docs.bucketprotocol.io/mechanisms',
#   'text_content': 'System Overview Security GitBook',
#   'links': ['https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/introduction/key-advantages',
#    'https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign',
#    'https://docs.bucketprotocol.io/mechanisms/system-overview',
#    'https://docs.bucketprotocol.io/mechanisms/terminology',
#    'https://docs.bucketprotocol.io/mechanisms/borrowing',
#    'https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck',
#    'https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations',
#    'https://docs.bucketprotocol.io/mechanisms/peg-stability-module',
#    'https://docs.bucketprotocol.io/mechanisms/redemptions',
#    'https://docs.bucketprotocol.io/mechanisms/recovery-mode',
#    'https://docs.bucketprotocol.io/mechanisms/flash-loan',
#    'https://docs.bucketprotocol.io/mechanisms/protocol-revenue',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details',
#    'https://docs.bucketprotocol.io/outro/oracles',
#    'https://docs.bucketprotocol.io/outro/security',
#    'https://docs.bucketprotocol.io/outro/faq',
#    'https://docs.bucketprotocol.io/outro/contracts',
#    'https://docs.bucketprotocol.io/outro/links',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/introduction',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service']},
#  {'url': 'https://docs.bucketprotocol.io/bucket-campaign',
#   'text_content': 'Security GitBook',
#   'links': ['https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/introduction/key-advantages',
#    'https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign',
#    'https://docs.bucketprotocol.io/mechanisms/system-overview',
#    'https://docs.bucketprotocol.io/mechanisms/terminology',
#    'https://docs.bucketprotocol.io/mechanisms/borrowing',
#    'https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck',
#    'https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations',
#    'https://docs.bucketprotocol.io/mechanisms/peg-stability-module',
#    'https://docs.bucketprotocol.io/mechanisms/redemptions',
#    'https://docs.bucketprotocol.io/mechanisms/recovery-mode',
#    'https://docs.bucketprotocol.io/mechanisms/flash-loan',
#    'https://docs.bucketprotocol.io/mechanisms/protocol-revenue',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details',
#    'https://docs.bucketprotocol.io/outro/oracles',
#    'https://docs.bucketprotocol.io/outro/security',
#    'https://docs.bucketprotocol.io/outro/faq',
#    'https://docs.bucketprotocol.io/outro/contracts',
#    'https://docs.bucketprotocol.io/outro/links',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/introduction',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service']},
#  {'url': 'https://docs.bucketprotocol.io/introduction',
#   'text_content': 'Introduction Security GitBook',
#   'links': ['https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/',
#    'https://docs.bucketprotocol.io/introduction/key-advantages',
#    'https://docs.bucketprotocol.io/bucket-campaign/bucket-x-sui-wallet-campaign',
#    'https://docs.bucketprotocol.io/mechanisms/system-overview',
#    'https://docs.bucketprotocol.io/mechanisms/terminology',
#    'https://docs.bucketprotocol.io/mechanisms/borrowing',
#    'https://docs.bucketprotocol.io/mechanisms/buck-savings-rate-bsr-and-sbuck',
#    'https://docs.bucketprotocol.io/mechanisms/tank-and-liquidations',
#    'https://docs.bucketprotocol.io/mechanisms/peg-stability-module',
#    'https://docs.bucketprotocol.io/mechanisms/redemptions',
#    'https://docs.bucketprotocol.io/mechanisms/recovery-mode',
#    'https://docs.bucketprotocol.io/mechanisms/flash-loan',
#    'https://docs.bucketprotocol.io/mechanisms/protocol-revenue',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-upward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/scenarios-of-downward-depeg',
#    'https://docs.bucketprotocol.io/price-stability-and-depeg-analysis/other-special-situations-and-details',
#    'https://docs.bucketprotocol.io/outro/oracles',
#    'https://docs.bucketprotocol.io/outro/security',
#    'https://docs.bucketprotocol.io/outro/faq',
#    'https://docs.bucketprotocol.io/outro/contracts',
#    'https://docs.bucketprotocol.io/outro/links',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/introduction',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/smart-contract-audit',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/formal-verification',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/market-risk-assessment',
#    'https://docs.bucketprotocol.io/external-audits-and-analysis/terms-of-service']}]
