# %%
print("Q")

# %%
from sheet_utils import get_sheet_df

protocol_docs_df = get_sheet_df("main")
# Out:
# /var/folders/wl/dn85m0dj6sq9rlt60_rh8_f00000gr/T/ipykernel_46596/2618418596.py:3: DeprecationWarning: [Deprecated][in version 6.0.0]: client_factory will be replaced by gspread.http_client types
#   protocol_docs_df = get_sheet_df("main")

# %%
# Out:
#       Protocol Name                                 Documentation Link
# 0         Aftermath                    https://docs.aftermath.finance/
# 1           AlphaFi                          https://docs.alphafi.xyz/
# 2           Bluefin                   https://learn.bluefin.io/bluefin
# 3   Bucket Protocol                    https://docs.bucketprotocol.io/
# 4    Cetus Protocol              https://cetus-1.gitbook.io/cetus-docs
# 5          DeepBook             https://docs.sui.io/standards/deepbook
# 6          DoubleUp               https://unihouse.gitbook.io/doubleup
# 7             FlowX                        https://docs.flowx.finance/
# 8   Haedal Protocol  https://haedal-protocol.gitbook.io/haedal-prot...
# 9       Kai Finance                          https://docs.kai.finance/
# 10            Kriya                        https://docs.kriya.finance/
# 11       Metastable                           https://docs.mstable.io/
# 12             Mole                            https://doc-en.mole.fi/
# 13             NAVI  https://naviprotocol.gitbook.io/navi-protocol-...
# 14          OmniBTC             https://omnibtclabs.gitbook.io/omnibtc
# 15          Scallop                           https://docs.scallop.io/
# 16          Strater                          https://docs.strater.xyz/
# 17     Sudo Finance                         https://docs.sudo.finance/
# 18              Sui                               https://docs.sui.io/
# 19          Suilend                           https://docs.suilend.fi/
# 20            SuiNS                             https://docs.suins.io/
# 21           Turbos                   https://turbos.gitbook.io/turbos
# 22            Typus                        https://docs.typus.finance/
# 23           Walrus                          https://docs.walrus.site/
# 24    The Move Book                             https://move-book.com/

# %%
import glob
import json
from datetime import datetime

# Get today's date in YYYYMMDD format
date_str = datetime.now().strftime("%Y%m%d")

# List all embedding files with the specified pattern
embed_files = glob.glob(f"{date_str}_*_embed.1.3.json")
print("\nEmbedding files:")
for f in embed_files:
    doc_url = f.replace(f"{date_str}_", "").replace("_embed.1.3.json", "")
    name = protocol_docs_df[
        protocol_docs_df["Documentation Link"].apply(lambda x: doc_url in x)
    ]["Protocol Name"].to_list()[0]
    with open(f, "r") as f:
        data = json.load(f)
        for doc in data:
            doc["source"] = name
            # Generate output filename
        output_file = f"{date_str}_{name}.1.4.json"

        # Save processed data
        with open(output_file, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=4)

        print(f"Saved processed data to {output_file}")
# Out:
# Embedding files:
# Saved processed data to 20250207_Turbos.1.4.json
# Saved processed data to 20250207_Cetus Protocol.1.4.json
# Saved processed data to 20250207_Bucket Protocol.1.4.json
# Saved processed data to 20250207_Haedal Protocol.1.4.json
# Saved processed data to 20250207_Scallop.1.4.json
# Saved processed data to 20250207_Kriya.1.4.json
# Saved processed data to 20250207_NAVI.1.4.json
# Saved processed data to 20250207_Aftermath.1.4.json
# Saved processed data to 20250207_Walrus.1.4.json
# Saved processed data to 20250207_Bluefin.1.4.json
# Saved processed data to 20250207_Sudo Finance.1.4.json
# Saved processed data to 20250207_Mole.1.4.json
# Saved processed data to 20250207_AlphaFi.1.4.json
# Saved processed data to 20250207_Metastable.1.4.json
# Saved processed data to 20250207_SuiNS.1.4.json
# Saved processed data to 20250207_Kai Finance.1.4.json
# Saved processed data to 20250207_Strater.1.4.json
# Saved processed data to 20250207_OmniBTC.1.4.json
# Saved processed data to 20250207_DeepBook.1.4.json
# Saved processed data to 20250207_Suilend.1.4.json
# Saved processed data to 20250207_Typus.1.4.json
# Saved processed data to 20250207_DoubleUp.1.4.json
# Saved processed data to 20250207_FlowX.1.4.json
